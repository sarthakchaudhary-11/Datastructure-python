# %% [markdown]
# <a href="https://colab.research.google.com/github/chsarthak/Datastructure-python/blob/main/SEABORN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#SEABORN >> Seaborn is a Python data visualization library based on matplotlib.
#It provides a high-level interface for drawing attractive and informative statistical graphics.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warning
warning.filterwarning('ignore')

# %%
#WHY SEABORN?
#Because :
# 1.More attractive plots
# 2.More options of statistical plots

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('exercise')
df
# Out:
#     Unnamed: 0  id     diet  pulse    time     kind
# 0            0   1  low fat     85   1 min     rest
# 1            1   1  low fat     85  15 min     rest
# 2            2   1  low fat     88  30 min     rest
# 3            3   2  low fat     90   1 min     rest
# 4            4   2  low fat     92  15 min     rest
# ..         ...  ..      ...    ...     ...      ...
# 85          85  29   no fat    135  15 min  running
# 86          86  29   no fat    130  30 min  running
# 87          87  30   no fat     99   1 min  running
# 88          88  30   no fat    111  15 min  running
# 89          89  30   no fat    150  30 min  running
#
# [90 rows x 6 columns]

# %%
df.shape
# Out:
# (90, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  90 non-null     int64
#  1   id          90 non-null     int64
#  2   diet        90 non-null     category
#  3   pulse       90 non-null     int64
#  4   time        90 non-null     category
#  5   kind        90 non-null     category
# dtypes: category(3), int64(3)
# memory usage: 2.9 KB

# %%
df.dtypes
# Out:
# Unnamed: 0       int64
# id               int64
# diet          category
# pulse            int64
# time          category
# kind          category
# dtype: object

# %%
# numerical data plotting
#relplot --> relationship between categorial data and numerical data or relationship between two variables.
#relplot --> relationship plot

# %%
df
# Out:
#     Unnamed: 0  id     diet  pulse    time     kind
# 0            0   1  low fat     85   1 min     rest
# 1            1   1  low fat     85  15 min     rest
# 2            2   1  low fat     88  30 min     rest
# 3            3   2  low fat     90   1 min     rest
# 4            4   2  low fat     92  15 min     rest
# ..         ...  ..      ...    ...     ...      ...
# 85          85  29   no fat    135  15 min  running
# 86          86  29   no fat    130  30 min  running
# 87          87  30   no fat     99   1 min  running
# 88          88  30   no fat    111  15 min  running
# 89          89  30   no fat    150  30 min  running
#
# [90 rows x 6 columns]

# %%
#how pulse is increasing with time >> scatterplot / bydefault relplot makes scatter plot

sns.relplot (x = 'pulse', y = 'time' , data = df) # relplot showing relationship between two variables

# %%
sns.relplot (x = 'id', y = 'pulse' , data = df , hue = 'diet') # hue differentiates by using different color shades

# %%
sns.relplot (x = 'id', y = 'pulse' , data = df , hue = 'kind' )

# %%
time = np.arange(100)
value = np.random.rand(100)
df = pd.DataFrame({'time': time , 'value': value})
df
# Out:
#     time     value
# 0      0  0.948282
# 1      1  0.625202
# 2      2  0.248509
# 3      3  0.185360
# 4      4  0.051385
# ..   ...       ...
# 95    95  0.349812
# 96    96  0.258318
# 97    97  0.553761
# 98    98  0.328274
# 99    99  0.442308
#
# [100 rows x 2 columns]

# %%
#line plot
sns.relplot(x = 'time', y = 'value', kind='line', data = df , sort=True)

# %%
fmri = sns.load_dataset('fmri')
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.relplot(x = 'timepoint', y='signal', kind='line', data=fmri, hue='event' , style='event')

# %%
#removes dashes from the chart
sns.relplot(x = 'timepoint', y='signal', kind='line', data=fmri, hue='event' , style='event', dashes = False)

# %%
sns.relplot(x = 'timepoint', y='signal', kind='line', data=fmri, hue='event' , style='event',markers=True)

# %%
exercise = sns.load_dataset('exercise')
exercise
# Out:
#     Unnamed: 0  id     diet  pulse    time     kind
# 0            0   1  low fat     85   1 min     rest
# 1            1   1  low fat     85  15 min     rest
# 2            2   1  low fat     88  30 min     rest
# 3            3   2  low fat     90   1 min     rest
# 4            4   2  low fat     92  15 min     rest
# ..         ...  ..      ...    ...     ...      ...
# 85          85  29   no fat    135  15 min  running
# 86          86  29   no fat    130  30 min  running
# 87          87  30   no fat     99   1 min  running
# 88          88  30   no fat    111  15 min  running
# 89          89  30   no fat    150  30 min  running
#
# [90 rows x 6 columns]

# %%
sns.relplot(x ='id',y='pulse',data=exercise, hue='kind' , col='diet')

# %%
#categorical plots
exercise
# Out:
#     Unnamed: 0  id     diet  pulse    time     kind
# 0            0   1  low fat     85   1 min     rest
# 1            1   1  low fat     85  15 min     rest
# 2            2   1  low fat     88  30 min     rest
# 3            3   2  low fat     90   1 min     rest
# 4            4   2  low fat     92  15 min     rest
# ..         ...  ..      ...    ...     ...      ...
# 85          85  29   no fat    135  15 min  running
# 86          86  29   no fat    130  30 min  running
# 87          87  30   no fat     99   1 min  running
# 88          88  30   no fat    111  15 min  running
# 89          89  30   no fat    150  30 min  running
#
# [90 rows x 6 columns]

# %%
exercise.dtypes
# Out:
# Unnamed: 0       int64
# id               int64
# diet          category
# pulse            int64
# time          category
# kind          category
# dtype: object

# %%
sns.catplot(x='id',y='time',data=exercise)

# %%
#Box plot>> to see outliners
sns.catplot(x='diet',y='pulse',data=exercise,kind='box')

# %%
#violen plots
sns.catplot(x='diet',y='pulse',data=exercise,kind='violin')

# %%
sns.barplot(x='diet',y='pulse',data=exercise)
# Out:
# <Axes: xlabel='diet', ylabel='pulse'>

# %%
#jointplot
sns.jointplot(x='id',y='pulse',data=exercise)

# %%
sns.jointplot(x='id',y='pulse',data=exercise,kind='reg')

# %%
sns.jointplot(x='id',y='pulse',data=exercise,kind='hex')

# %%
sns.jointplot(x='id',y='pulse',data=exercise,kind='kde') # kernel density estimator >> used by meterological dept.

# %%
sns.pairplot(exercise) # makes plots wrt all numerical columns

# %%
sns.pairplot(exercise,hue='diet')
